# %% [markdown]
# # Chapter 06: Capstone Project
#
# ## End-to-End Data Analysis of the Tips Dataset
#
# This capstone project brings together the skills developed across Chapters 01 through 05.
# You will perform a complete data analysis workflow on the **Tips** dataset, covering:
#
# - **Data Exploration** with Pandas
# - **Data Manipulation** including filtering, grouping, and pivot tables
# - **Visualization** using Matplotlib and Seaborn
#
# The Tips dataset records information about restaurant bills, including the total bill,
# tip amount, customer demographics, day of the week, meal time, and party size.
#
# Work through each question below, writing your code in the empty cells provided.
# Once you have completed the exercise, compare your work with `02_project_solution.ipynb`.

# %% [markdown]
# ## Setup
#
# Run the cell below to import the required libraries and load the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the tips dataset
tips = sns.load_dataset('tips')

# Configure plot aesthetics
sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ---
# ## Part 1: Data Exploration
#
# Get familiar with the dataset by examining its structure, contents, and basic statistics.

# %% [markdown]
# ### Q1: Display the first 10 rows and the shape of the dataset
#
# Print the first 10 rows using `.head()` and then print the shape of the DataFrame
# to understand how many rows and columns it contains.

# %% [markdown]
# ### Q2: Get summary statistics and check for missing values
#
# Use `.describe()` to obtain summary statistics for the numerical columns.
# Then check whether any column contains missing values using `.isnull().sum()`.

# %% [markdown]
# ### Q3: What are the unique values in each categorical column?
#
# Identify the categorical columns (`sex`, `smoker`, `day`, `time`) and print
# the unique values for each one.

# %% [markdown]
# ### Q4: What is the data type of each column?
#
# Display the data types for every column in the DataFrame using `.dtypes`.

# %% [markdown]
# ### Q5: How many records are there for each day of the week?
#
# Count the number of records per day using `.value_counts()` on the `day` column.

# %% [markdown]
# ---
# ## Part 2: Data Manipulation
#
# Transform and aggregate the data to extract meaningful summaries.

# %% [markdown]
# ### Q6: Create a new column `tip_percentage`
#
# Calculate the tip as a percentage of the total bill:
#
# ```
# tip_percentage = tip / total_bill * 100
# ```
#
# Add this as a new column to the DataFrame and display the first few rows to verify.

# %% [markdown]
# ### Q7: What is the average tip percentage by day?
#
# Group the data by `day` and compute the mean of `tip_percentage`.
# Sort the result in descending order.

# %% [markdown]
# ### Q8: Filter for parties of 4 or more and find their average total bill
#
# Select only the rows where `size >= 4`, then calculate the mean `total_bill`
# for that subset.

# %% [markdown]
# ### Q9: Group by `sex` and `smoker` — calculate mean `total_bill` and `tip`
#
# Perform a multi-column groupby on `sex` and `smoker`, then compute the mean
# for both `total_bill` and `tip`.

# %% [markdown]
# ### Q10: Create a pivot table — day vs time, values = tip_percentage, aggfunc = mean
#
# Build a pivot table with `day` as the index, `time` as the columns,
# `tip_percentage` as the values, and `mean` as the aggregation function.

# %% [markdown]
# ---
# ## Part 3: Visualization
#
# Create plots to visually explore the relationships and distributions in the data.

# %% [markdown]
# ### Q11: Create a histogram of `total_bill` with 20 bins
#
# Plot a histogram showing the distribution of total bill amounts.
# Use 20 bins and add a title and axis labels.

# %% [markdown]
# ### Q12: Create a scatter plot of `total_bill` vs `tip`, colored by `time`
#
# Use Seaborn to create a scatter plot where the x-axis is `total_bill`,
# the y-axis is `tip`, and the points are colored according to whether
# the meal was Lunch or Dinner. Include a title and legend.

# %% [markdown]
# ### Q13: Create a box plot comparing `tip_percentage` across days
#
# Use Seaborn to produce a box plot with `day` on the x-axis and
# `tip_percentage` on the y-axis. Add a descriptive title.

# %% [markdown]
# ### Q14: Create a heatmap of the correlation matrix for numerical columns
#
# Compute the correlation matrix using `.corr()` on the numerical columns,
# then visualize it with `sns.heatmap()`. Annotate each cell with its value
# and use an appropriate color map.

# %% [markdown]
# ### Q15: Create a FacetGrid — scatter of `total_bill` vs `tip`, faceted by `day`, colored by `sex`
#
# Use `sns.FacetGrid` to create a grid of scatter plots. Each subplot should
# correspond to a different day. Points within each subplot should be colored
# by the `sex` column. Add a legend.

# %% [markdown]
# ---
#
# Well done on completing the capstone project! Compare your solutions with
# `02_project_solution.ipynb` to review alternative approaches and additional insights.
